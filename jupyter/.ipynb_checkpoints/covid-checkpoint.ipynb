# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score

# %% [markdown]
# ---

# %% [markdown]
# # ➡️ Load dataset

# %% [markdown]
# ---

# %%
covid = pd.read_csv('../input/covid-19.csv')

# %% [markdown]
# ---

# %% [markdown]
# # ➡️ Exploring info

# %% [markdown]
# ---

# %%
covid
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 270685  270686      2/7/2021      1/7/2021   ชาย  28.0   ปี    Thailand
# 270686  270687      2/7/2021      1/7/2021  หญิง  50.0   ปี    Thailand
# 270687  270688      2/7/2021      1/7/2021  หญิง  31.0   ปี    Thailand
# 270688  270689      2/7/2021      1/7/2021  หญิง  40.0   ปี    Thailand
# 270689  270690      2/7/2021      1/7/2021  หญิง  36.0   ปี         NaN
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 270685         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 270686         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 270687         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 270688         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 270689         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 270685     กรุงเทพมหานคร               NaN
# 270686     กรุงเทพมหานคร               NaN
# 270687     กรุงเทพมหานคร               NaN
# 270688     กรุงเทพมหานคร               NaN
# 270689     กรุงเทพมหานคร               NaN
#
# [270690 rows x 11 columns]

# %%
covid.tail(10)
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 270680  270681      2/7/2021      1/7/2021   ชาย  32.0   ปี    Thailand
# 270681  270682      2/7/2021      1/7/2021   ชาย  35.0   ปี    Thailand
# 270682  270683      2/7/2021      1/7/2021   ชาย  21.0   ปี    Thailand
# 270683  270684      2/7/2021      1/7/2021   ชาย  39.0   ปี    Thailand
# 270684  270685      2/7/2021      1/7/2021   ชาย  29.0   ปี    Thailand
# 270685  270686      2/7/2021      1/7/2021   ชาย  28.0   ปี    Thailand
# 270686  270687      2/7/2021      1/7/2021  หญิง  50.0   ปี    Thailand
# 270687  270688      2/7/2021      1/7/2021  หญิง  31.0   ปี    Thailand
# 270688  270689      2/7/2021      1/7/2021  หญิง  40.0   ปี    Thailand
# 270689  270690      2/7/2021      1/7/2021  หญิง  36.0   ปี         NaN
#
#        province_of_isolation              risk province_of_onset  \
# 270680         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ     กรุงเทพมหานคร
# 270681         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ     กรุงเทพมหานคร
# 270682         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ     กรุงเทพมหานคร
# 270683         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ     กรุงเทพมหานคร
# 270684         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ     กรุงเทพมหานคร
# 270685         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ     กรุงเทพมหานคร
# 270686         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ     กรุงเทพมหานคร
# 270687         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ     กรุงเทพมหานคร
# 270688         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ     กรุงเทพมหานคร
# 270689         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ     กรุงเทพมหานคร
#
#        district_of_onset
# 270680               NaN
# 270681               NaN
# 270682               NaN
# 270683               NaN
# 270684               NaN
# 270685               NaN
# 270686               NaN
# 270687               NaN
# 270688               NaN
# 270689               NaN

# %%
print(covid.columns)
# Out:
# Index(['No.', 'announce_date', 'Notified date', 'sex', 'age', 'Unit',
#        'nationality', 'province_of_isolation', 'risk', 'province_of_onset',
#        'district_of_onset'],
#       dtype='object')

# %%
(covid.province_of_isolation).unique()
# Out:
# array(['กรุงเทพมหานคร', 'นครปฐม', 'นนทบุรี', 'ประจวบคีรีขันธ์', 'ภูเก็ต',
#        'เชียงใหม่', 'กระบี่', 'สมุทรปราการ', 'ชลบุรี', nan,
#        'นครศรีธรรมราช', 'สุพรรณบุรี', 'ปทุมธานี', 'สุโขทัย', 'นราธิวาส',
#        'ยะลา', 'เพชรบูรณ์', 'สุราษฎร์ธานี', 'ปัตตานี', 'ขอนแก่น',
#        'ร้อยเอ็ด', 'กาฬสินธุ์', 'นครราชสีมา', 'พัทลุง', 'อุบลราชธานี',
#        'สระบุรี', 'ระยอง', 'นครนายก', 'สงขลา', 'กาญจนบุรี', 'ลพบุรี',
#        'สุรินทร์', 'เชียงราย', 'สมุทรสาคร', 'บุรีรัมย์', 'ปราจีนบุรี',
#        'ศรีสะเกษ', 'ฉะเชิงเทรา', 'เลย', 'หนองบัวลำภู', 'อุดรธานี', 'แพร่',
#        'สระแก้ว', 'ราชบุรี', 'จันทบุรี', 'ยโสธร', 'ตาก', 'มหาสารคาม',
#        'เพชรบุรี', 'ตรัง', 'อุทัยธานี', 'นครสวรรค์', 'มุกดาหาร',
#        'อำนาจเจริญ', 'พิษณุโลก', 'หนองคาย', 'ชัยภูมิ', 'แม่ฮ่องสอน',
#        'พะเยา', 'นครพนม', 'ลำพูน', 'อุตรดิตถ์', 'ชุมพร', 'สมุทรสงคราม',
#        'พระนครศรีอยุธยา', 'ลำปาง', 'สกลนคร', 'สตูล', 'พังงา', 'พิจิตร',
#        'สิงห์บุรี', 'กำแพงเพชร', 'ชัยนาท', 'อ่างทอง', 'ระนอง', 'ตราด',
#        'น่าน', 'บึงกาฬ'], dtype=object)

# %%
(covid.nationality).unique()
# Out:
# array(['China', 'Thailand', 'Italy', 'United Kingdom', 'Singapore',
#        'Japan', 'France', 'Denmark', 'Belgium',
#        'United States of America', 'Germany', 'Pakistan', 'Canada',
#        'Burma', nan, 'Malaysia', 'Switzerland', 'Philippines', 'Iran',
#        'Sweden', 'New Zealand', 'Finland', 'Brazil', 'Netherlands',
#        'Israel', 'Australia', 'Cambodia', 'India', 'Spain', 'Ukraine',
#        'Portugal', 'Uzbekistan', 'Laos', 'Korea, South', 'India-Thailand',
#        'Indonesia', 'Russia', 'Albania', 'Taiwan', 'Serbia', 'Vietnam',
#        'Hungary', 'Liberia', 'Kuwait', 'Tunisia', 'Mexico', 'ต่างด้าว',
#        'Kazakhstan', 'Palestine', 'Mali', 'Yemen', 'Sudan', 'Egypt',
#        'Bangladesh', 'Qatar', 'Ethiopia', 'Turkey', 'Laotian',
#        'Macedonia', 'Portuguese', 'Bahrain', 'Nepal', 'Lithuania',
#        'Syria', 'Kenya', 'Oman', 'Azerbaijan', 'Maldives', 'Czechia',
#        'American', 'Italian', 'deutsch', 'American ', 'Norway', 'Belarus',
#        'Estonia', 'Nigeria', 'Bulgaria', 'Libya', 'Jordan', 'Romania',
#        'Argentina', 'Afghanistan', 'china', 'Ireland', 'ไทใหญ่',
#        'Croatia', 'Eritrea', 'United Arab Emirates', 'Hong Kong',
#        'thailand', 'Slovenia', 'Cameroon', 'Uganda', 'ไทยใหญ่', 'Somalia',
#        'Greece', 'Iceland', 'American Samoa', 'Lebanon', 'Poland',
#        'South Africa', 'Austria', 'Zimbabwe', 'Mauritius', 'france',
#        'Sri Lanka', 'Sierra Leone', 'ไม่ระบุ', 'Kyrgyzstan', 'Latvia',
#        'Armenia', 'Palestinian', 'Algeria', 'Kosovo', 'ไม่มีสัญชาติ',
#        "Cote D'Ivoire", 'Iraq', 'Tajikistan', 'บราซิล', 'yemen',
#        'British', 'japan', 'Cuba', 'Namibia', 'Myanmar', 'ลาว', 'พม่า',
#        'Lao', 'Bermuda', 'French Guiana', 'Brunei', 'Tanzania', 'laos',
#        'Mongolia', 'Malta', 'อเมริกา', 'Luxembourg', 'อเมริกัน', 'Guinea',
#        'burma', 'Congo (Brazzaville)', 'india', 'taiwan', 'Cambodian',
#        'Colombia', 'คูเวต', 'Gambia, The', 'Malawi', 'Ghana', 'Burmese',
#        'Nicaragua', 'Dominican Republic', 'Chinese', 'Vietnamese',
#        'Laotian / Lao', 'Filipino', 'Indian', 'South Korean', 'Swedish',
#        'Japanese', 'Taiwanese', 'Gambia', 'South African', 'Indonesian',
#        'Iranian', 'Nepalese / Nepali', 'Malaysian', 'Guyanese', 'Guinean',
#        'Malian', 'Spanish', 'Austrian', 'Canadian', 'Pakistani',
#        'Norwegian', 'Israeli', 'Australian', 'pakistani', 'Sri Lankan',
#        'French', 'Turkish', 'Nigerian', 'Other', 'Swiss', 'Kuwaiti',
#        'Tanzanian', 'Ghanaian', 'German', 'Timor-Leste',
#        'British / English', 'Thai', 'Danish', 'Venezuelan', 'Ivorian',
#        'Romanian', 'thai', 'Maldivian', 'African', 'Russian', 'Mongolian',
#        'Guyana', 'Haitian', 'Ugandan', 'Moroccan', 'Kenyan', 'Serbian',
#        'Dutch', 'Senegal', 'Syrian', 'Singaporean', 'congo', 'Oatari',
#        'cambodian', 'Belgian', 'Brazilian', 'Egyptian', 'Irish',
#        'Bangladeshi', 'canadian', 'Afghan / Afghani', 'burmese',
#        'Mauritians', 'Colombian', 'Uzbek', 'chinese', 'ไนจีเรีย'],
#       dtype=object)

# %%
(covid.risk).unique()
# Out:
# array(['คนต่างชาติเดินทางมาจากต่างประเทศ',
#        'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้',
#        'อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น',
#        'คนไทยเดินทางกลับจากต่างประเทศ', 'State Quarantine',
#        'บุคลากรด้านการแพทย์และสาธารณสุข',
#        'ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว', 'สถานบันเทิง',
#        'สัมผัสผู้เดินทางจากต่างประเทศ', 'สนามมวย', 'Cluster ตลาดพรพัฒน์',
#        nan, 'พิธีกรรมทางศาสนา', 'ปอดอักเสบ (Pneumonia)', 'อื่นๆ',
#        'อยู่ระหว่างการสอบสวน', 'ระบุไม่ได้',
#        'ไปสถานที่แออัด เช่น งานแฟร์ คอนเสิร์ต',
#        'การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน',
#        'ตรวจก่อนทำหัตถการ', 'ศูนย์กักกัน ผู้ต้องกัก',
#        'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AOQ',
#        'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ',
#        'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า HQ/AHQ',
#        'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า OQ', 'ผู้ติดเชื้อในประเทศ',
#        'Cluster สมุทรสาคร', 'Cluster ระยอง', 'Cluster บ่อนพัทยา/ชลบุรี',
#        'Cluster ตลาดบางพลี', 'Cluster ชลบุรี', 'Cluster จันทบุรี',
#        'Cluster ตราด ', 'Cluster ตราด', 'Cluster บ่อนไก่อ่างทอง',
#        "Cluster Memory 90's กรุงเทพมหานคร", 'Cluster บ่อนเทพารักษ์',
#        'Cluster โรงงาน standard can', 'Cluster New Jazz กรุงเทพมหานคร',
#        'คนไทยเดินทางมาจากต่างประเทศ', 'Cluster ชลบุรี โรงเบียร์ 90',
#        'Cluster โรงงาน Big Star', 'Cluster Icon siam',
#        'Cluster มหาสารคาม',
#        'Cluster สมุทรปราการ (โรงงาน บริษัทเมทัล โปรดักส์)',
#        'Cluster เครือคัสเซ่อร์พีคโฮลดิ้ง (CPG,CPH)', 'SHUI',
#        'Cluster บางแค', 'Cluster โรงงานทำขนม บางขุนเทียน',
#        'Cluster The Lounge Salaya', 'แรงงานต่างด้าวตรวจก่อนขึ้นทะเบียน',
#        'Cluster ผับ Thonglor', 'ตรวจสุขภาพแรงงานต่างด้าว',
#        'Cluster โรงงาน  Big Star', 'Cluster ตลาดบางแค',
#        'Cluster ตลาดบางแค/คลองขวาง', 'รอประสาน',
#        'cluster ชลบุรี\n(อยู่ระหว่างการสอบสวน)',
#        'สัมผัสใกล้ชิดผู้ป่วยยืนยันก่อนหน้า', 'ผู้ป่วย PUI',
#        'ไปเที่ยวสถานบันเทิงในอุบลที่พบการระบาดของโรค Ubar',
#        'ไปสถานที่เสี่ยง เช่น ตลาด สถานที่ชุมชน', 'ผับหัวหิน',
#        'Cluster งานมอเตอร์ โชว์', 'อยู่ระหว่างสอบสวน',
#        'สัมผัสใกล้ชิดผู้ป่วยยันยันก่อนหน้า',
#        'Cluster สถานบันเทิงย่านทองหล่อ', 'ร้านอาหาร',
#        'สัมผัสผู้ป่วยยืนยัน', 'ไปยังพื้นที่ที่มีการระบาด',
#        'คนไทยมาจากพื้นที่เสี่ยง',
#        'ผู้เดินทางมาจากพื้นที่เสี่ยง กรุงเทพมหานคร.',
#        'ไปยัง/มาจาก พื้นที่ระบาดกรุงเทพมหานครมหานคร',
#        'ปอดอักเสบ Pneumonia', 'Cluster ปากช่อง',
#        'สัมผัสผู้ติดเชื้อยืนยัน\nอยู่ระหว่างสอบสวน', 'ค้นหาเชิงรุก',
#        'สัมผัสผู้ป่วยยืนยัน อยู่ระหว่างสอบสวน',
#        'เดินทางมาจากพื้นที่มีการระบาดของโรค', 'ระหว่างสอบสวน',
#        'Cluster ชลบุรี บริษัทไดกิ้น', 'ระหว่างการสอบสวนโรค',
#        'ไปแหล่งชุมชน/สถานที่คนหนาแน่น', 'Cluster คลองเตย',
#        'สัมผัสผู้ติดเชื้อยืนยัน อยู่ระหว่างสอบสวน',
#        'อาศัย/เดินทางไปในพื้นที่ที่มีการระบาด', 'อยู่ระหว่างสอบสวนโรค',
#        'สัมผัสในสถานพยาบาล', 'Cluster ระยอง วิริยะประกันภัย', 'Refer in',
#        'Cluster กรุงเทพมหานคร. คลองเตย',
#        'สัมผัสผู้ป่วยยืนยัน อยุ๋ระหว่างสอบสวน',
#        'สัมผัสผู้ป่วยที่ติดโควิด', 'อยุ่ระหว่างสอบสวน',
#        'Cluster จันทบุรี (ชาวกินี)', 'Cluster จันทบุรี (ชาวกินี )',
#        'Cluster ตลาดนนทบุรี', 'Cluster ตลาดสี่มุมเมือง',
#        'Cluster โรงงาน QPP ประจวบฯ', 'Cluster สมุทรปราการ GRP Hightech',
#        'Cluster เรือนจำพิเศษกรุงเทพ', 'Cluster จนท. สนามบินสุวรรณภูมิ',
#        'Cluster ห้างแสงทอง (สายล่าง)', 'Cluster ทัณฑสถานหญิงกลาง',
#        'Cluster ทันฑสถานบำบัดพิเศษกลาง',
#        'Cluster ทัณฑสถานโรงพยาบาลราชทัณฑ์', 'Cluster เรือนจำพิเศษธนบุรี',
#        'Cluster เรือนจำพิเศษมีนบุรี', 'Cluster เรือนจำกลางคลองเปรม',
#        'Cluster บริษัทศรีสวัสดิ์', 'ACF เคหะหลักสี่', 'ACF รองเมือง',
#        'ACF สนามกีฬาไทย-ญี่ปุ่น', 'ACF สนามกีฬาธูปะเตมีย์', 'ACF สีลม',
#        'สถานที่ทำงาน', 'สัมผัสผู้ป่วยยืนยัน \n อยู่ระหว่างสอบสวน',
#        'ทัณฑสถาน/เรือนจำ', 'สัมผัสสามีสะอาด เขตบ้าน (รพ.มหาชัย 2)',
#        'อยู่ระหว่างการสอบสวน\n', 'Cluster สมุทรปราการ ตลาดเคหะบางพลี',
#        '2.สัมผัสผู้ติดเชื้อ', 'อื่น'], dtype=object)

# %% [markdown]
# ---

# %% [markdown]
# # ➡️ Remove Features

# %% [markdown]
# ---

# %%
covid = covid.drop(['No.', 'Notified date', 'Unit', 'province_of_onset', 'district_of_onset'], axis = 1)

# %%
covid.tail(10)
# Out:
#        announce_date   sex   age nationality province_of_isolation  \
# 270680      2/7/2021   ชาย  32.0    Thailand         กรุงเทพมหานคร
# 270681      2/7/2021   ชาย  35.0    Thailand         กรุงเทพมหานคร
# 270682      2/7/2021   ชาย  21.0    Thailand         กรุงเทพมหานคร
# 270683      2/7/2021   ชาย  39.0    Thailand         กรุงเทพมหานคร
# 270684      2/7/2021   ชาย  29.0    Thailand         กรุงเทพมหานคร
# 270685      2/7/2021   ชาย  28.0    Thailand         กรุงเทพมหานคร
# 270686      2/7/2021  หญิง  50.0    Thailand         กรุงเทพมหานคร
# 270687      2/7/2021  หญิง  31.0    Thailand         กรุงเทพมหานคร
# 270688      2/7/2021  หญิง  40.0    Thailand         กรุงเทพมหานคร
# 270689      2/7/2021  หญิง  36.0         NaN         กรุงเทพมหานคร
#
#                     risk
# 270680  ทัณฑสถาน/เรือนจำ
# 270681  ทัณฑสถาน/เรือนจำ
# 270682  ทัณฑสถาน/เรือนจำ
# 270683  ทัณฑสถาน/เรือนจำ
# 270684  ทัณฑสถาน/เรือนจำ
# 270685  ทัณฑสถาน/เรือนจำ
# 270686  ทัณฑสถาน/เรือนจำ
# 270687  ทัณฑสถาน/เรือนจำ
# 270688  ทัณฑสถาน/เรือนจำ
# 270689  ทัณฑสถาน/เรือนจำ

# %% [markdown]
# ---

# %% [markdown]
# # ➡️ Cleansing data

# %% [markdown]
# ---

# %%
(covid.isnull()).sum()         # see number of NULL each column
# Out:
# announce_date                0
# sex                      16469
# age                      27185
# nationality              20439
# province_of_isolation      508
# risk                      1079
# dtype: int64

# %%
covid = covid.dropna(axis = 0, subset = ['sex', 'age',
                                         'nationality', 'province_of_isolation',
                                         'risk'])
(covid.isnull()).sum()
# Out:
# announce_date            0
# sex                      0
# age                      0
# nationality              0
# province_of_isolation    0
# risk                     0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # ➡️ Preparing (re-format)

# %% [markdown]
# ---

# %%
covid.dtypes          # see type
# Out:
# announce_date             object
# sex                       object
# age                      float64
# nationality               object
# province_of_isolation     object
# risk                      object
# dtype: object

# %%
covid['announce_date'] = pd.to_datetime(covid['announce_date'], format = '%d/%m/%Y')    # convert variable type

# %%
covid.dtypes
# Out:
# announce_date            datetime64[ns]
# sex                              object
# age                             float64
# nationality                      object
# province_of_isolation            object
# risk                             object
# dtype: object

# %%
# separate year, month and day

covid['announce_y'] = covid['announce_date'].dt.year
covid['announce_m'] = covid['announce_date'].dt.month
covid['announce_d'] = covid['announce_date'].dt.day

# %%
covid = covid.drop(['announce_date'], axis = 1)

covid.tail(10)
# Out:
#          sex   age nationality province_of_isolation              risk  \
# 270679   ชาย  49.0    Thailand         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ
# 270680   ชาย  32.0    Thailand         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ
# 270681   ชาย  35.0    Thailand         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ
# 270682   ชาย  21.0    Thailand         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ
# 270683   ชาย  39.0    Thailand         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ
# 270684   ชาย  29.0    Thailand         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ
# 270685   ชาย  28.0    Thailand         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ
# 270686  หญิง  50.0    Thailand         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ
# 270687  หญิง  31.0    Thailand         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ
# 270688  หญิง  40.0    Thailand         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ
#
#         announce_y  announce_m  announce_d
# 270679        2021           7           2
# 270680        2021           7           2
# 270681        2021           7           2
# 270682        2021           7           2
# 270683        2021           7           2
# 270684        2021           7           2
# 270685        2021           7           2
# 270686        2021           7           2
# 270687        2021           7           2
# 270688        2021           7           2

# %%
covid.loc[(covid["announce_y"] == 2021)]
# Out:
#          sex   age nationality province_of_isolation                 risk  \
# 124     หญิง  55.0    Thailand              ปทุมธานี  Cluster ตลาดพรพัฒน์
# 6885    หญิง  40.0    Thailand         กรุงเทพมหานคร    Cluster สมุทรสาคร
# 6886    หญิง  21.0    Thailand              ปทุมธานี        Cluster ระยอง
# 6887    หญิง  20.0    Thailand                นครปฐม          สถานบันเทิง
# 6888    หญิง  47.0    Thailand             สมุทรสาคร    Cluster สมุทรสาคร
# ...      ...   ...         ...                   ...                  ...
# 270684   ชาย  29.0    Thailand         กรุงเทพมหานคร     ทัณฑสถาน/เรือนจำ
# 270685   ชาย  28.0    Thailand         กรุงเทพมหานคร     ทัณฑสถาน/เรือนจำ
# 270686  หญิง  50.0    Thailand         กรุงเทพมหานคร     ทัณฑสถาน/เรือนจำ
# 270687  หญิง  31.0    Thailand         กรุงเทพมหานคร     ทัณฑสถาน/เรือนจำ
# 270688  หญิง  40.0    Thailand         กรุงเทพมหานคร     ทัณฑสถาน/เรือนจำ
#
#         announce_y  announce_m  announce_d
# 124           2021           3           6
# 6885          2021           1           1
# 6886          2021           1           1
# 6887          2021           1           1
# 6888          2021           1           1
# ...            ...         ...         ...
# 270684        2021           7           2
# 270685        2021           7           2
# 270686        2021           7           2
# 270687        2021           7           2
# 270688        2021           7           2
#
# [222661 rows x 8 columns]

# %%
covid.loc[(covid.index >= 120) & (covid.index <= 130)]      # see a outlier
# Out:
#       sex   age nationality province_of_isolation  \
# 120   ชาย  51.0    Thailand         กรุงเทพมหานคร
# 121  หญิง  29.0    Thailand         กรุงเทพมหานคร
# 122   ชาย  21.0    Thailand         กรุงเทพมหานคร
# 123  หญิง  23.0    Thailand         กรุงเทพมหานคร
# 124  หญิง  55.0    Thailand              ปทุมธานี
# 125   ชาย  35.0    Thailand         กรุงเทพมหานคร
# 126   ชาย  51.0    Thailand         กรุงเทพมหานคร
# 127   ชาย  36.0    Thailand               สุโขทัย
# 128   ชาย  37.0    Thailand         กรุงเทพมหานคร
# 129  หญิง  56.0    Thailand         กรุงเทพมหานคร
# 130  หญิง  32.0    Thailand         กรุงเทพมหานคร
#
#                                                   risk  announce_y  \
# 120                                            สนามมวย        2020
# 121                                        สถานบันเทิง        2020
# 122                                        สถานบันเทิง        2020
# 123                                        สถานบันเทิง        2020
# 124                                Cluster ตลาดพรพัฒน์        2021
# 125        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้        2020
# 126        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้        2020
# 127        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้        2020
# 128        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้        2020
# 129  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...        2020
# 130        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้        2020
#
#      announce_m  announce_d
# 120           3          16
# 121           3          16
# 122           3          16
# 123           3          16
# 124           3           6
# 125           3          16
# 126           3          16
# 127           3          16
# 128           3          16
# 129           3          16
# 130           3          16

# %%
covid['person_count'] = 1

covid.tail(10)
# Out:
#          sex   age nationality province_of_isolation              risk  \
# 270679   ชาย  49.0    Thailand         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ
# 270680   ชาย  32.0    Thailand         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ
# 270681   ชาย  35.0    Thailand         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ
# 270682   ชาย  21.0    Thailand         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ
# 270683   ชาย  39.0    Thailand         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ
# 270684   ชาย  29.0    Thailand         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ
# 270685   ชาย  28.0    Thailand         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ
# 270686  หญิง  50.0    Thailand         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ
# 270687  หญิง  31.0    Thailand         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ
# 270688  หญิง  40.0    Thailand         กรุงเทพมหานคร  ทัณฑสถาน/เรือนจำ
#
#         announce_y  announce_m  announce_d  person_count
# 270679        2021           7           2             1
# 270680        2021           7           2             1
# 270681        2021           7           2             1
# 270682        2021           7           2             1
# 270683        2021           7           2             1
# 270684        2021           7           2             1
# 270685        2021           7           2             1
# 270686        2021           7           2             1
# 270687        2021           7           2             1
# 270688        2021           7           2             1

# %%
covid_2021_04 = covid.loc[(covid["announce_y"] == 2021) & (covid["announce_m"] >= 4) & (covid["announce_m"] <= 6)]
covid_2021_04
# Out:
#          sex   age nationality province_of_isolation               risk  \
# 28863    ชาย  27.0       Burma             สมุทรสาคร  Cluster สมุทรสาคร
# 28864   หญิง  18.0       Burma             สมุทรสาคร  Cluster สมุทรสาคร
# 28865    ชาย  28.0       Burma             สมุทรสาคร  Cluster สมุทรสาคร
# 28866   หญิง  30.0       Burma             สมุทรสาคร  Cluster สมุทรสาคร
# 28867   หญิง  30.0       Burma             สมุทรสาคร  Cluster สมุทรสาคร
# ...      ...   ...         ...                   ...                ...
# 259065  หญิง  62.0    Thailand                 สงขลา   ทัณฑสถาน/เรือนจำ
# 259066  หญิง  63.0    Thailand                 สงขลา   ทัณฑสถาน/เรือนจำ
# 259067  หญิง  34.0    Thailand                 สงขลา   ทัณฑสถาน/เรือนจำ
# 259068  หญิง  45.0    Thailand                 สงขลา   ทัณฑสถาน/เรือนจำ
# 259069   ชาย  37.0    Thailand                 สงขลา   ทัณฑสถาน/เรือนจำ
#
#         announce_y  announce_m  announce_d  person_count
# 28863         2021           4           1             1
# 28864         2021           4           1             1
# 28865         2021           4           1             1
# 28866         2021           4           1             1
# 28867         2021           4           1             1
# ...            ...         ...         ...           ...
# 259065        2021           6          30             1
# 259066        2021           6          30             1
# 259067        2021           6          30             1
# 259068        2021           6          30             1
# 259069        2021           6          30             1
#
# [193311 rows x 9 columns]

# %%
covid_2021_04 = pd.pivot_table(covid_2021_04,
                               index = ["announce_y","announce_m","announce_d"],
                               values = ["person_count"],
                               aggfunc = {"person_count":np.sum})

covid_2021_04 = covid_2021_04.reset_index()
covid_2021_04
# Out:
#     announce_y  announce_m  announce_d  person_count
# 0         2021           4           1            26
# 1         2021           4           2            58
# 2         2021           4           3            84
# 3         2021           4           4            96
# 4         2021           4           5           183
# ..         ...         ...         ...           ...
# 86        2021           6          26          3851
# 87        2021           6          27          3812
# 88        2021           6          28          4741
# 89        2021           6          29          4160
# 90        2021           6          30          4203
#
# [91 rows x 4 columns]

# %%
covid_2021_04.index = covid_2021_04.index + 1       # change index
covid_2021_04
# Out:
#     announce_y  announce_m  announce_d  person_count
# 1         2021           4           1            26
# 2         2021           4           2            58
# 3         2021           4           3            84
# 4         2021           4           4            96
# 5         2021           4           5           183
# ..         ...         ...         ...           ...
# 87        2021           6          26          3851
# 88        2021           6          27          3812
# 89        2021           6          28          4741
# 90        2021           6          29          4160
# 91        2021           6          30          4203
#
# [91 rows x 4 columns]

# %% [markdown]
# ---

# %% [markdown]
# # ➡️ Plot chart (pre training)

# %% [markdown]
# ---

# %%
plt.figure(figsize = (15, 7))
sns.lineplot(covid_2021_04.index, 'person_count', data = covid_2021_04, marker = 'o', markersize = 10)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ---

# %% [markdown]
# # ➡️ Training data

# %% [markdown]
# ---

# %%
x = ((covid_2021_04.index).values).reshape(-1,1)    # features

y = covid_2021_04.person_count                      # labels

# %%
poly_features = PolynomialFeatures(degree = 5)
x_poly = poly_features.fit_transform(x)            # fit data
model = LinearRegression()
model.fit(x_poly, y)                               # train data
# Out:
# LinearRegression()

# %%
y_poly_pred = model.predict(x_poly)

# %% [markdown]
# ---

# %% [markdown]
# # ➡️ Plot chart

# %% [markdown]
# ---

# %%
sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = 15,7
plt.scatter(x, y, color = 'b', s = 12)
plt.plot(x, y_poly_pred, linewidth = '2', color = 'r')       # model line
plt.ylabel('New cases')
plt.xlabel('Date')
plt.title('')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # ➡️ Evaluation

# %% [markdown]
# ---

# %%
print('r2 = {:0.5f}'.format(r2_score(y, y_poly_pred)))
# Out:
# r2 = 0.79773

# %% [markdown]
# ---

# %% [markdown]
# # ➡️ Prediction

# %% [markdown]
# ---

# %%
x_input = [[92], [93], [94]]
pred = model.predict(poly_features.fit_transform(x_input))

# %%
print('As a result of the estimate, Covid-19 new case amount on July 1st would be {:0.0f}.'.format(pred[0]))
# Out:
# As a result of the estimate, Covid-19 new case amount on July 1st would be 4965.

# %% [markdown]
# ### On July 1, the exact Covid-19 new case number is 5533.
#
# ![image](../pictures/0107.jpg)

# %%
print('As a result of the estimate, Covid-19 new case amount on July 2nd would be {:0.0f}.'.format(pred[1]))
# Out:
# As a result of the estimate, Covid-19 new case amount on July 2nd would be 5314.

# %% [markdown]
# ### On July 2, the exact Covid-19 new case number is 6087.
#
# ![image](../pictures/0207.jpg)

# %%
print('As a result of the estimate, Covid-19 new case amount on July 3rd would be {:0.0f}.'.format(pred[2]))
# Out:
# As a result of the estimate, Covid-19 new case amount on July 3rd would be 5700.

# %% [markdown]
# ### On July 3, the exact Covid-19 new case number is 6230.
#
# ![image](../pictures/0307.jpg)
